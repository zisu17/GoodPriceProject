# %%
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
df = pd.read_csv('./data/서울시 착한가격음식점(종합).csv',encoding='euc-kr')

# %%
df['별점']
index1 = df[df['별점']=='-'].index
df.drop(index1,inplace=True)

# %%
df['총개수']
index1 = df[df['총개수']=='0'].index
df.drop(index1,inplace=True)

# %%
df['키워드1']
index2=df[df['키워드1']!='음식이 맛있어요'].index
df.drop(index2,inplace=True)

# %%
df.reset_index(inplace=True)
df.drop(['index'],axis=1,inplace=True)

# %%
df
# Out:
#      업소아이디              업소명  분류코드 분류코드명                       업소 주소  \
# 0     1739         목우촌부추삼겹살     1    한식  서울특별시 관악구 남현1길 68-10 (남현동)
# 1     6764         토방 닭 한마리     1    한식    서울특별시 관악구 신림로22길 5 (신림동)
# 2     3986  왕세숫대야냉면(행복을파는집)     1    한식     서울특별시 강서구 공항대로 423(등촌동)
# 3     8633          돌마리유황오리     1    한식      서울특별시 송파구 가락로 66 (석촌동)
# 4     8171           벧엘 칼국수     1    한식   서울특별시 송파구 마천로41길 22 (마천동)
# ..     ...              ...   ...   ...                         ...
# 445   9560          옛날무쇠가마솥     1    한식  서울특별시 서울 마포구 서강로1길 12-5 1층
# 446   9156            삼겹살데이     1    한식     서울특별시 서대문구 가좌로 29 (연희동)
# 447   9315              보물쌈     1    한식  서울특별시 동작구 상도로 296-2 (상도1동)
# 448   9279             가정식당     1    한식   서울특별시 강남구 학동로77길 20 (청담동)
# 449   9069             두부마을     1    한식   서울특별시 강북구 오현로31길 109 (번동)
#
#               업소 전화번호                                            찾아오시는 길  \
# 0    588-7399          전철 2호선 4호선 사당역에서 5번출구로 나오시면 (구)관악등기소쪽 먹자골목으로 5...
# ...

# %%
df1=df[['별점','추천수','총개수','개수1']]
df1
# Out:
#         별점  추천수   총개수  개수1
# 0    4.36   257    62   47
# 1    4.52   214   109   83
# 2    4.44   163  1279  732
# 3    4.41   155    63   57
# 4    4.12   106   180  123
# ..     ...  ...   ...  ...
# 445  4.47     0    86   59
# 446  4.35     0    79   60
# 447  4.08     0   130   71
# 448  4.13     0    51   18
# 449  4.35     0   219  174
#
# [450 rows x 4 columns]

# %%
df1 = df1.astype({"별점":"float","추천수":"float","총개수":"float","개수1":"float"})

# %%
df1.corr()
# Out:
#            별점       추천수       총개수       개수1
# 별점   1.000000 -0.006414  0.133455  0.157725
# 추천수 -0.006414  1.000000  0.125592  0.101847
# 총개수  0.133455  0.125592  1.000000  0.985026
# 개수1  0.157725  0.101847  0.985026  1.000000

# %%
# 그래프 기본 설정
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (10, 8)

# %%
plt.scatter(df1['별점'],df1['추천수'])

# %%
plt.scatter(df1['별점'],df1['총개수'])

# %%
plt.scatter(df1['별점'],df1['개수1'])

# %% [markdown]
# 착한 가격 업소가 많은 동일수록 가격대가 저렴한지?

# %%
df['행정구']
# Out:
# 0       관악구
# 1       관악구
# 2       강서구
# 3       송파구
# 4       송파구
#        ...
# 445     마포구
# 446    서대문구
# 447     동작구
# 448     강남구
# 449     강북구
# Name: 행정구, Length: 450, dtype: object

# %%
gu = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']

# %%
gu = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']
c = []
for i in gu :
    count = 0
    for j in range(len(df)) :
        if df['행정구'][j]==i :
            count+=1
        else :
            continue
    c.append(count)

# %%
df['행정구'][10]
# Out:
# '광진구'

# %%
df_gu = pd.DataFrame((zip(gu,c)),columns=['행정구','개수'])

# %%
df_gu
# Out:
#      행정구  개수
# 0    강남구  83
# 1    강동구   5
# 2    강북구   6
# 3    강서구  11
# 4    관악구  27
# 5    광진구  17
# 6    구로구  26
# 7    금천구  18
# 8    노원구   9
# 9    도봉구  25
# 10  동대문구   5
# 11   동작구  53
# 12   마포구  14
# 13  서대문구  18
# 14   서초구   5
# 15   성동구   6
# 16   성북구   9
# 17   송파구  26
# 18   양천구   8
# 19  영등포구  14
# 20   용산구  15
# 21   은평구  11
# 22   종로구   6
# 23    중구  21
# 24   중랑구  12

# %%
list(df['행정구']).count('강남구')
# Out:
# 83

# %%
df2 = pd.read_csv('./data/서울시 착한가격음식점(메뉴가격나열).csv',encoding='euc-kr')

# %%
df2['상품가격']
# Out:
# 0       12000.0
# 1        8000.0
# 2        5000.0
# 3       12000.0
# 4        5500.0
#          ...
# 1628     7000.0
# 1629     7000.0
# 1630    11000.0
# 1631     7000.0
# 1632     7000.0
# Name: 상품가격, Length: 1633, dtype: float64

# %%
df2['상품가격']
# Out:
# 0       12000.0
# 1        8000.0
# 2        5000.0
# 3       12000.0
# 4        5500.0
#          ...
# 1628     7000.0
# 1629     7000.0
# 1630    11000.0
# 1631     7000.0
# 1632     7000.0
# Name: 상품가격, Length: 1633, dtype: float64

# %%
df2['상품가격']
index2=df2[df2['상품가격'].isnull].index
df2.drop(index2,inplace=True)

# %%
df2.reset_index(inplace=True)
df2.drop(['index'],axis=1,inplace=True)

# %%
df2
# Out:
#       업소아이디       업소명  분류코드 분류코드명                           업소 주소  \
# 0      1739  목우촌부추삼겹살     1    한식      서울특별시 관악구 남현1길 68-10 (남현동)
# 1      1739  목우촌부추삼겹살     1    한식      서울특별시 관악구 남현1길 68-10 (남현동)
# 2      1739  목우촌부추삼겹살     1    한식      서울특별시 관악구 남현1길 68-10 (남현동)
# 3      1739  목우촌부추삼겹살     1    한식      서울특별시 관악구 남현1길 68-10 (남현동)
# 4      4325    청진동해장국     1    한식  서울특별시 관악구 관악로 105 (봉천동) 동산빌딩1층
# ...     ...       ...   ...   ...                             ...
# 1628   9279      가정식당     1    한식       서울특별시 강남구 학동로77길 20 (청담동)
# 1629   9279      가정식당     1    한식       서울특별시 강남구 학동로77길 20 (청담동)
# 1630   9069      두부마을     1    한식       서울특별시 강북구 오현로31길 109 (번동)
# 1631   9069      두부마을     1    한식       서울특별시 강북구 오현로31길 109 (번동)
# 1632   9069      두부마을     1    한식       서울특별시 강북구 오현로31길 109 (번동)
#
#                업소 전화번호                                            찾아오시는 길  \
# 0     588-7399          전철 2호선 4호선 사당역에서 5번출구로 나오시면 (구)관악등기소쪽 먹자골목으로 5...
# ...

# %%
gu = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구','서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']
s = []
for i in gu :
    count = 0
    price = 0
    for j in range(len(df2)) :
        if df2['행정구'][j]==i :
            count+=1
            price+=df2['상품가격'][j]
            
        else :
            continue
    a = price/count
    s.append(a)

# %%
s
# Out:
# [7530.952380952381,
#  5947.368421052632,
#  8593.75,
#  5271.0526315789475,
#  5831.496062992126,
#  5843.835616438356,
#  nan,
#  11464.0,
#  5577.419354838709,
#  5723.684210526316,
#  7552.631578947368,
#  9330.252100840336,
#  6214.492753623188,
#  6192.5,
#  6081.818181818182,
#  6058.823529411765,
#  5800.0,
#  6763.333333333333,
#  nan,
#  7545.454545454545,
#  6697.321428571428,
#  7234.482758620689,
#  5856.25,
#  nan,
#  4821.621621621622]

# %%
df_gu = pd.DataFrame((zip(gu,c,s)),columns=['행정구','개수','평균가격'])
df_gu
# Out:
#      행정구  개수          평균가격
# 0    강남구  83   7530.952381
# 1    강동구   5   5947.368421
# 2    강북구   6   8593.750000
# 3    강서구  11   5271.052632
# 4    관악구  27   5831.496063
# 5    광진구  17   5843.835616
# 6    구로구  26           NaN
# 7    금천구  18  11464.000000
# 8    노원구   9   5577.419355
# 9    도봉구  25   5723.684211
# 10  동대문구   5   7552.631579
# 11   동작구  53   9330.252101
# 12   마포구  14   6214.492754
# 13  서대문구  18   6192.500000
# 14   서초구   5   6081.818182
# 15   성동구   6   6058.823529
# 16   성북구   9   5800.000000
# 17   송파구  26   6763.333333
# 18   양천구   8           NaN
# 19  영등포구  14   7545.454545
# 20   용산구  15   6697.321429
# 21   은평구  11   7234.482759
# 22   종로구   6   5856.250000
# 23    중구  21           NaN
# 24   중랑구  12   4821.621622

# %%
df2['상품가격'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1633 entries, 0 to 1632
# Series name: 상품가격
# Non-Null Count  Dtype
# --------------  -----
# 1627 non-null   float64
# dtypes: float64(1)
# memory usage: 12.9 KB
